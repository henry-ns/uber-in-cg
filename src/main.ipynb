# %%
import pandas as pd
import matplotlib.pyplot as plt

import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go

#from uber_rides.session import Session
#from uber_rides.client import UberRidesClient

# %%
tls.set_credentials_file(username='henry.ns', api_key='qanypj121rQRayco2QJE')
mapbox_access_token = 'pk.eyJ1IjoiaGVucnktbnMiLCJhIjoiY2pwb2lvNXRsMGVheDN5bWZqZDR6NXBoYiJ9.gthMeJC3ciyTBad4fokj2Q'

# %%
session = Session(server_token='nskNWfhogB13VV2kzHjmmpu-2BloJgXqwDQ3h6aR')
client = UberRidesClient(session)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ee374c7c5b77> in <module>()
# ----> 1 session = Session(server_token='nskNWfhogB13VV2kzHjmmpu-2BloJgXqwDQ3h6aR')
#       2 client = UberRidesClient(session)
#
# NameError: name 'Session' is not defined

# %%
geo = pd.read_json('../res/geo.json')

# %%
geo
# Out:
#                                               address  \
# 0                Alto Branco, Campina Grande, Paraíba
# 1   Rua Padre Pedro Serrão, Liberdade, Campina Gra...
# 2                      Araxá, Campina Grande, Paraíba
# 3                     Nações, Campina Grande, Paraíba
# 4                  Conceição, Campina Grande, Paraíba
# 5                     Cuites, Campina Grande, Paraíba
# 6             Kampina-Grande, Campina Grande, Paraíba
# 7         Jardim Continental, Campina Grande, Paraíba
# 8   Rua Professora Maria Helena de Menezes, Malvin...
# 9             Jardim Tavares, Campina Grande, Paraíba
# 10                  Jeremias, Campina Grande, Paraíba
# 11                            Campina Grande, Paraíba
# 12                 Lauritzen, Campina Grande, Paraíba
# 13                  Louzeiro, Campina Grande, Paraíba
# 14               Monte Santo, Campina Grande, Paraíba
# 15            Novo Bodocongo, Campina Grande, Paraíba
# ...

# %%
cg = plt.scatter(x=geo['lat'], y=geo['lng'])

# %%
data = [
    go.Scattermapbox(
        lat=geo['lat'],
        lon=geo['lng'],
        mode='markers',
        marker=dict(
            size=9
        ),
        text=geo['address'],
    )
]

# %%
layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=geo['lat'][11],
            lon=geo['lng'][11]
        ),
        pitch=0,
        zoom=11
    ),
)

# %%
fig = dict(data=data, layout=layout)

# %%
py.iplot(fig, filename='Mapbox')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~henry.ns/25.embed" height="525px" width="100%"></iframe>
