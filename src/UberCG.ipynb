# %%
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go

# %%
df = pd.read_csv("../res/bairros_estimativas.csv")
for i, j in zip(df['horario'], range(0, df.shape[0])):
    df['horario'][j] = i[:16]
n_column = []
for i in df.columns:
    n_column.append(i.replace(', Campina Grande, Paraíba', ''))
df.columns = n_column
df = df.set_index("horario")
# Out:
# /home/felipe/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.head()
# Out:
#                   Alto Branco  Rua Padre Pedro Serrão, Liberdade, 58414-265  \
# horario
# 2018-12-15 09:47          180                                           180
# 2018-12-15 10:18          180                                           180
# 2018-12-15 10:49          240                                           180
# 2018-12-15 11:20          180                                           240
# 2018-12-15 11:51          240                                           240
#
#                   Araxá  Nações  Conceição  Cuites  Kampina-Grande  \
# horario
# 2018-12-15 09:47    180     360        120     240             240
# 2018-12-15 10:18    600     300        120     300             180
# 2018-12-15 10:49    480     300        240     420             120
# 2018-12-15 11:20    420     240        120     300             180
# 2018-12-15 11:51    360     240        240     360             180
#
#                   Jardim Continental  \
# horario
# 2018-12-15 09:47                 360
# 2018-12-15 10:18                 360
# 2018-12-15 10:49                 480
# 2018-12-15 11:20                 360
# 2018-12-15 11:51                 420
#
#                   Rua Professora Maria Helena de Menezes, Malvinas, 58433-528  \
# horario
# 2018-12-15 09:47                                                360
# 2018-12-15 10:18                                                540
# 2018-12-15 10:49                                                420
# 2018-12-15 11:20                                                180
# 2018-12-15 11:51                                                540
#
#                   Jardim Tavares      ...        Malvinas  Serrotão  Pedregal  \
# horario                               ...
# 2018-12-15 09:47             180      ...             240       240       180
# 2018-12-15 10:18             240      ...             420       540       420
# 2018-12-15 10:49             120      ...             240       480       360
# 2018-12-15 11:20             120      ...             180       480       180
# 2018-12-15 11:51             240      ...             480       660       600
#
#                   Prata  Ramadinha  Santa Cruz  Santa Rosa, Santa Cruz  \
# horario
# 2018-12-15 09:47    180        180         240                     360
# 2018-12-15 10:18    300        540         360                     180
# 2018-12-15 10:49    240        360         240                     240
# 2018-12-15 11:20    120        360         240                     360
# 2018-12-15 11:51    360        480         180                     300
#
#                   Rua São Januário, Serrotão, 58437-690  \
# horario
# 2018-12-15 09:47                                    180
# 2018-12-15 10:18                                    540
# 2018-12-15 10:49                                    480
# 2018-12-15 11:20                                    480
# 2018-12-15 11:51                                    600
#
#                   Rua São Lucas, Jeremias, 58404-200  Universitário
# horario
# 2018-12-15 09:47                                 360            360
# 2018-12-15 10:18                                 180            180
# 2018-12-15 10:49                                 360            300
# 2018-12-15 11:20                                 300            300
# 2018-12-15 11:51                                 180            360
#
# [5 rows x 69 columns]

# %%
df.iloc[10].plot.barh(figsize=(10,20))

# %%
df['Alto Branco'].plot(figsize=(15,10))

# %%
df.iloc[0].plot.box()

# %%
df['Alto Branco'].plot.box()

# %%
pd.DataFrame(df['Alto Branco'].describe())
# Out:
#        Alto Branco
# count    17.000000
# mean    232.941176
# std      92.179492
# min     120.000000
# 25%     180.000000
# 50%     180.000000
# 75%     300.000000
# max     480.000000

# %%
dd = []
for i in range(df.shape[0]):
    dd.append(df.iloc[i].describe())
pd.DataFrame(dd)
# Out:
#                   count        mean         std    min    25%    50%    75%  \
# 2018-12-15 09:47   69.0  258.260870   95.593449  120.0  180.0  240.0  300.0
# 2018-12-15 10:18   69.0  323.478261  160.145394  120.0  180.0  300.0  420.0
# 2018-12-15 10:49   69.0  260.000000  111.143786  120.0  180.0  240.0  300.0
# 2018-12-15 11:20   69.0  245.217391  102.248381  120.0  180.0  240.0  300.0
# 2018-12-15 11:51   69.0  314.782609  135.501342  120.0  240.0  300.0  420.0
# 2018-12-15 12:22   69.0  254.782609  100.507663  120.0  180.0  240.0  300.0
# 2018-12-15 12:53   69.0  311.304348  113.784019  120.0  240.0  300.0  420.0
# 2018-12-15 13:24   69.0  245.217391   95.833936  120.0  180.0  240.0  300.0
# 2018-12-15 13:55   69.0  223.478261   80.290394  120.0  180.0  240.0  240.0
# 2018-12-15 14:26   69.0  290.434783  106.749222  120.0  180.0  300.0  360.0
# 2018-12-15 14:57   69.0  260.869565  112.638661  120.0  180.0  240.0  300.0
# 2018-12-15 15:27   69.0  222.608696   96.583584  120.0  120.0  180.0  300.0
# 2018-12-15 15:58   69.0  224.347826  102.720040   60.0  120.0  180.0  300.0
# 2018-12-15 16:29   69.0  327.826087  122.868528  120.0  240.0  300.0  420.0
# 2018-12-15 17:00   69.0  356.521739  152.930454  120.0  240.0  360.0  420.0
# 2018-12-15 17:32   69.0  255.652174   99.046606  120.0  180.0  240.0  300.0
# 2018-12-15 18:03   69.0  206.956522   89.431281  120.0  120.0  180.0  240.0
#
#                     max
# 2018-12-15 09:47  600.0
# 2018-12-15 10:18  720.0
# 2018-12-15 10:49  540.0
# 2018-12-15 11:20  540.0
# 2018-12-15 11:51  660.0
# 2018-12-15 12:22  600.0
# 2018-12-15 12:53  600.0
# 2018-12-15 13:24  600.0
# 2018-12-15 13:55  420.0
# 2018-12-15 14:26  540.0
# 2018-12-15 14:57  660.0
# 2018-12-15 15:27  480.0
# 2018-12-15 15:58  480.0
# 2018-12-15 16:29  600.0
# 2018-12-15 17:00  900.0
# 2018-12-15 17:32  480.0
# 2018-12-15 18:03  540.0

# %%
df_mean = df.reset_index().drop('horario', axis=1)
df_mean
mean = {}
for column in df_mean.columns:
    m = df_mean[column].mean()
    mean[column] = m
df_mean = pd.DataFrame(data=mean, index=['media'])
print(df_mean.transpose().nlargest(10, 'media'))
df_mean
# Out:
#                                                          media
# Travessa Santa Terezinha, 58410                     494.117647
# Novo Bodocongo                                      405.882353
# Araxá                                               398.823529
# Serrotão                                            395.294118
# Rua São Januário, Serrotão, 58437-690               388.235294
# Rua Almirante Alexandrino, Acácio Figueiredo, 5...  384.705882
# Cidades                                             356.470588
# Jardim Continental                                  356.470588
# Ramadinha                                           338.823529
# Jeremias                                            328.235294
#        Acácio Figueiredo, Presidente Médici  Alto Branco       Araxá  \
# media                            225.882353   232.941176  398.823529
#
#        Avenida Belo Horizonte, Presidente Médici, 58423-100  \
# media                                         254.117647
#
#        Bela Vista, Universitário   Bodocongó  Campina Grande, Paraíba  \
# media                 222.352941  264.705882               232.941176
#
#        Castelo Branco      Catolé  Centenário  \
# media      261.176471  243.529412  268.235294
#
#                         ...                    São José      Tambor  \
# media                   ...                       240.0  289.411765
#
#        Travessa Maria Rosa, Monte Santo, 58400-742  \
# media                                   310.588235
#
#        Travessa Santa Terezinha, 58410  Três Irmãs  UBS Ronaldo Cunha Lima  \
# media                       494.117647  243.529412              275.294118
#
#        Universitário      Velame  Vila Cabral  \
# media     292.941176  250.588235   268.235294
#
#        Vila Vitória, José Pinheiro, 58407-333
# media                              211.764706
#
# [1 rows x 69 columns]

# %%
df_mean.transpose().plot.box(legend=False, figsize=(15,15))
